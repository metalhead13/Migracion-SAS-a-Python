# %%
#Scrip 07
#
#%pip install pandas

# %%
import pandas as pd
import numpy as np
import datetime

pd.set_option('display.precision', 2)
pd.set_option('display.float_format',  '{:2f}'.format)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# %%
def corregirColumna(df, col):
    df1 = df[col].astype(str).copy()
    df1 = df1.apply(lambda x: list(x.split(".",1))[0])
    return df1

# %%
# %%time
path='Script_08/'
file = 'APTP_BASE_AMBAS_COMPANIAS_CA.csv'
#CALP: Replace  error_bad_lines=False, warn_bad_lines=False with  on_bad_lines='skip'
dfp = pd.read_csv(file, sep=';',  on_bad_lines='skip', encoding='utf-8-sig', low_memory=False, dtype=str ,nrows=1000000) #,nrows=3000000           , nrows=741953                , encoding="latin1"
dfp.columns = dfp.columns.str.upper()
# Out:
# CPU times: user 57.4 s, sys: 5.08 s, total: 1min 2s
# Wall time: 1min 2s

# %%
#dfp.iloc[-1]

# %%
dfp.loc[dfp['ORIGEN']=='LIBERTY','ORIGEN'] = 'LIBER'
dfp.loc[dfp['USO']=='DESCONOCID','USO'] = 'DESCONOCIDO'

# %%
dfp['KEY'] = dfp['POLIZA'].astype(str) + '-' + dfp['ITEM'].astype(str) + '-' + dfp['ORIGEN'].astype(str)

# %%
dfp.head(3)
# Out:
#    SSEGURO   CAGENTE CAGRSEG   POLIZA ITEM     INI_VIG FIN_VIG_ORIG  \
# 0  2618871  00995032     NaN  6287875    1  2013-02-27   2014-02-27
# 1  3591452  07965010     NaN  6383242    3  2014-04-05   2015-04-05
# 2  3476389  07685025    3204  6372976    1  2014-01-29   2015-01-29
#
#   FIN_VIG_ACT DIAS_VIGENTE DIAS_SUSCRITOS VEH_CMARCA VEH_CMODELO VEH_CLASE  \
# 0  2014-02-27          365            365         14         510         L
# 1  2015-04-05          365            365         62         115         L
# 2  2014-01-29            0            365         48         516         L
#
#   VEH_CVERSION                   TVERSION         USO VEH_ANO PATENTE  \
# 0     14510002  OPTRA LS NB 1.6 16V MT AC  PARTICULAR    2004  XJ9745
# 1     62115001                   YARIS GL  PARTICULAR    2010  CDRW29
# 2     48516003          508 ACTIVE AT 1.6   COMERCIAL    2012  DYSV69
#
#   VEH_CTIPO   VEH_TIPO     TMARCA TMODELO      NUM_MOTOR CORREDOR_RUT  \
# ...

# %%
dfp[dfp.duplicated(['KEY'])]
dfp[dfp.duplicated()].sort_values('KEY')
dfp['KEY']
# Out:
# 0           6287875-1-LIBER
# 1           6383242-3-LIBER
# 2           6372976-1-LIBER
# 3          6894832-92-LIBER
# 4           6953759-1-LIBER
#                  ...
# 2999995      61404620-1-nan
# 2999996      61404620-1-nan
# 2999997      61404620-1-nan
# 2999998      61404620-1-nan
# 2999999      61404620-1-nan
# Name: KEY, Length: 3000000, dtype: object

# %%
#Ajuste de datos para comparar
#dfp['FLOTA1']=corregirColumna(dfp,'FLOTA1')
#dfp['FECHA_COTRENOV'] = pd.to_datetime(dfs['FECHA_COTRENOV'],format="%Y-%m-%d %H:%M:%S", errors = 'coerce').dt.strftime('%Y-%m-%d')

# %%
# %%time
path='Script_08/'
file = 'base_ambas_companias_CA.csv'
#CALP: Replace  error_bad_lines=False, warn_bad_lines=False with  on_bad_lines='skip'
dfs = pd.read_csv(file, sep=',',  on_bad_lines='skip', encoding='ISO-8859-1', low_memory=False, dtype=str, nrows=1000000) #,nrows=3000000           , nrows=741953                , encoding="latin1"
dfs.columns = dfs.columns.str.upper()
# Out:
# CPU times: user 1min 12s, sys: 5.96 s, total: 1min 18s
# Wall time: 1min 18s

# %%
#dfs.iloc[-1]

# %%
dfs.loc[dfs['ORIGEN']=='LIBERTY','ORIGEN'] = 'LIBER'

# %%
#validar si requiere crear key, ose usa la del archivo
dfs['KEY'] = dfs['POLIZA'].astype(str) + '-' + dfs['ITEM'].astype(str) + '-' + dfs['ORIGEN'].astype(str)

# %%
dfs['INI_VIG'] = pd.to_datetime(dfs['INI_VIG'], dayfirst=True)
dfs['FIN_VIG_ORIG'] = pd.to_datetime(dfs['FIN_VIG_ORIG'], dayfirst=True)
dfs['FIN_VIG_ACT'] = pd.to_datetime(dfs['FIN_VIG_ACT'], dayfirst=True)
dfs['DATE_UPDATE'] = pd.to_datetime(dfs['DATE_UPDATE'], dayfirst=True)
dfs['FECHA_COTRENOV'] = pd.to_datetime(dfs['FECHA_COTRENOV'],format="%d%b%Y:%H:%M:%S", errors = 'coerce').dt.strftime('%Y-%m-%d')
dfs['FECHA_NACIMIENTO'] = pd.to_datetime(dfs['FECHA_NACIMIENTO'], dayfirst=True)
dfs.loc[dfs['USO']=='DESCONOCID','USO'] = 'DESCONOCIDO'

# %%
dfs[dfs.duplicated(['KEY'])]
dfs[dfs.duplicated()].sort_values('KEY')
dfs['KEY']
# Out:
# 0          10546091-15029-PENTA
# 1            10437382-126-PENTA
# 2              17018263-1-PENTA
# 3            10434286-137-PENTA
# 4              18009965-3-PENTA
#                    ...
# 3308702        61482397-1-LIBER
# 3308703        61485816-1-LIBER
# 3308704        61447478-1-LIBER
# 3308705        61446987-1-LIBER
# 3308706        61470659-1-LIBER
# Name: KEY, Length: 3308707, dtype: object

# %%
dfp.head(3)
# Out:
#    SSEGURO   CAGENTE CAGRSEG   POLIZA ITEM     INI_VIG FIN_VIG_ORIG  \
# 0  2618871  00995032     NaN  6287875    1  2013-02-27   2014-02-27
# 1  3591452  07965010     NaN  6383242    3  2014-04-05   2015-04-05
# 2  3476389  07685025    3204  6372976    1  2014-01-29   2015-01-29
#
#   FIN_VIG_ACT DIAS_VIGENTE DIAS_SUSCRITOS VEH_CMARCA VEH_CMODELO VEH_CLASE  \
# 0  2014-02-27          365            365         14         510         L
# 1  2015-04-05          365            365         62         115         L
# 2  2014-01-29            0            365         48         516         L
#
#   VEH_CVERSION                   TVERSION         USO VEH_ANO PATENTE  \
# 0     14510002  OPTRA LS NB 1.6 16V MT AC  PARTICULAR    2004  XJ9745
# 1     62115001                   YARIS GL  PARTICULAR    2010  CDRW29
# 2     48516003          508 ACTIVE AT 1.6   COMERCIAL    2012  DYSV69
#
#   VEH_CTIPO   VEH_TIPO     TMARCA TMODELO      NUM_MOTOR CORREDOR_RUT  \
# ...

# %%
dfs.head(3)
# Out:
#   SSEGURO CAGENTE CAGRSEG    POLIZA   ITEM    INI_VIG FIN_VIG_ORIG  \
# 0     NaN     NaN     NaN  10546091  15029 2015-10-22   2016-10-22
# 1     NaN     NaN     NaN  10437382    126 2012-06-14   2013-06-14
# 2     NaN     NaN     NaN  17018263      1 2012-12-31   2013-12-31
#
#   FIN_VIG_ACT DIAS_VIGENTE DIAS_SUSCRITOS VEH_CMARCA VEH_CMODELO VEH_CLASE  \
# 0  2016-10-22          366            366         78         409         L
# 1  2013-06-14          365            365         78         405         L
# 2  2013-12-31          365            365         83         102         L
#
#   VEH_CVERSION      TVERSION         USO VEH_ANO PATENTE VEH_CTIPO  \
# 0          NaN  POLIZA PENTA  PARTICULAR    2012  DCXB29         5
# 1          NaN  POLIZA PENTA  PARTICULAR    2012  DXJS71         1
# 2          NaN  POLIZA PENTA  PARTICULAR    1995  NH8037         1
#
#         VEH_TIPO  TMARCA  TMODELO    NUM_MOTOR CORREDOR_RUT  \
# ...

# %%
#dfp.info(verbose=True)
dfp.isna().sum()
# Out:
# SSEGURO                 993111
# CAGENTE                 993035
# CAGRSEG                1899220
# POLIZA                       5
# ITEM                         0
# INI_VIG                      0
# FIN_VIG_ORIG                 0
# FIN_VIG_ACT                  0
# DIAS_VIGENTE                 5
# DIAS_SUSCRITOS               0
# VEH_CMARCA               12748
# VEH_CMODELO              86351
# VEH_CLASE                  941
# VEH_CVERSION            993972
# TVERSION                   937
# USO                          0
# VEH_ANO                  11813
# PATENTE                 275677
# VEH_CTIPO                82639
# VEH_TIPO                   981
# TMARCA                     938
# TMODELO                    938
# NUM_MOTOR                59013
# CORREDOR_RUT             10672
# CORREDOR                 10671
# COD_PRODUCTO                74
# PRODUCTO                    75
# COD_PLAN                    70
# PLAN                    179667
# DEDUCIBLE                11978
# ...

# %%
#dfs.info(verbose=True)
dfs.isna().sum()
# Out:
# SSEGURO                  1144188
# CAGENTE                  1144188
# CAGRSEG                  1974195
# POLIZA                         0
# ITEM                           0
# INI_VIG                        0
# FIN_VIG_ORIG                   0
# FIN_VIG_ACT                    0
# DIAS_VIGENTE                   0
# DIAS_SUSCRITOS                 0
# VEH_CMARCA                 37089
# VEH_CMODELO               154168
# VEH_CLASE                   5020
# VEH_CVERSION             1149209
# TVERSION                    5021
# USO                            0
# VEH_ANO                    36024
# PATENTE                   373478
# VEH_CTIPO                 149059
# VEH_TIPO                    5021
# TMARCA                      5021
# TMODELO                     5021
# NUM_MOTOR                 108518
# CORREDOR_RUT               30251
# CORREDOR                   30251
# COD_PRODUCTO                   0
# PRODUCTO                       1
# COD_PLAN                       0
# ...

# %%
#dfp['ORIGEN'].value_counts()

# %%
#dfs['ORIGEN'].value_counts()

# %%
#dfp['SSEGURO'] = dfp['SSEGURO'].astype(str)
#dfp['SSEGURO'] = dfp['SSEGURO'].str.replace(r'\.0$','', regex=True)

#dfs['SSEGURO'] = dfs['SSEGURO'].astype(str)
#dfs['SSEGURO'] = dfs['SSEGURO'].str.replace(r'\.0$','', regex=True)

# %%
dfp['KEY']
# Out:
# 0           6287875-1-LIBER
# 1           6383242-3-LIBER
# 2           6372976-1-LIBER
# 3          6894832-92-LIBER
# 4           6953759-1-LIBER
#                  ...
# 2999995      61404620-1-nan
# 2999996      61404620-1-nan
# 2999997      61404620-1-nan
# 2999998      61404620-1-nan
# 2999999      61404620-1-nan
# Name: KEY, Length: 3000000, dtype: object

# %%
dfs['KEY']
# Out:
# 0          10546091-15029-PENTA
# 1            10437382-126-PENTA
# 2              17018263-1-PENTA
# 3            10434286-137-PENTA
# 4              18009965-3-PENTA
#                    ...
# 3308702        61482397-1-LIBER
# 3308703        61485816-1-LIBER
# 3308704        61447478-1-LIBER
# 3308705        61446987-1-LIBER
# 3308706        61470659-1-LIBER
# Name: KEY, Length: 3308707, dtype: object

# %%
# si la llave del archivo dfs esta con la plabra completa,hay que generar nueva llave
   #dfs['KEY2'] = dfs['POLIZA'].astype(str) + '-' + dfs['ITEM'].astype(str) + '-' + dfs['ORIGEN'].astype(str)
  #dfs=dfs.sort_values(by=['KEY2'])
  #dfs.insert(0, 'KEY', dfs.pop('KEY'))
  #dfs.rename(columns = {'KEY':'KEY_ORIG', 'KEY2':'KEY'}, inplace = True)
  #dfs['KEY']

# %%
#dfs.loc[dfs['SSEGURO']=='999345',['SSEGURO','POLIZA','ITEM','NUM_ITEMS','ORIGEN','ANTERIOR','COD_MARCA_P','COD_MODELO_P','COD_TIPO_P','FORMAPAGO','CANAL','DURACION_PLAN','ORIGEN_MARCA','ANTIG_VEHICULO','PT_RO']]

# %%
dfp = dfp.drop_duplicates(subset = 'KEY').sort_values(by = 'KEY')
dfs = dfs.drop_duplicates(subset = 'KEY').sort_values(by = 'KEY')

# %%
len(dfp.index)  #  valida que no haya duplicados, deben ser el numero exacto de conteo al principo
# Out:
# 2643428

# %%
len(dfs.index)  #  valida que no haya duplicados, deben ser el numero exacto de conteo al principo
# Out:
# 3308707

# %%
df2 = pd.merge(dfs['KEY'], dfp['KEY'], 
               how='inner',
              left_on=['KEY'],
              right_on=['KEY'],
              left_index=False,
              right_index=False, 
              sort=True,
             suffixes=('_x', '_y'), copy=True, indicator=True,
             validate=None)
df2
# Out:
#                         KEY _merge
# 0        10361804-264-PENTA   both
# 1        10361804-265-PENTA   both
# 2        10362876-754-PENTA   both
# 3        10362876-755-PENTA   both
# 4        10392980-700-PENTA   both
# ...                     ...    ...
# 2640788     6999892-1-LIBER   both
# 2640789     6999893-1-LIBER   both
# 2640790     6999905-2-LIBER   both
# 2640791     6999905-3-LIBER   both
# 2640792     6999910-1-LIBER   both
#
# [2640793 rows x 2 columns]

# %%
df2.groupby(['_merge']).size()
# Out:
# _merge
# left_only           0
# right_only          0
# both          2640793
# dtype: int64

# %%
dfp = dfp[dfp['KEY'].isin(dfs['KEY'])].dropna(how = 'all')
dfp.shape
# Out:
# (2640793, 99)

# %%
dfs = dfs[dfs['KEY'].isin(dfp['KEY'])].dropna(how = 'all')
dfs.shape
# Out:
# (2640793, 100)

# %%
#  INICIA COMPARACION DE CAMPOS... KEY + CAMPO A ANALIZAR

# %%
### SSEGURO

dfp1 = dfp[['KEY', 'SSEGURO']]
dfs1 = dfs[['KEY', 'SSEGURO']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.SSEGURO_p != dfm.SSEGURO_s) & (~dfm.SSEGURO_s.isnull())].copy()
dfm1[['KEY','SSEGURO_p','SSEGURO_s']]
# Out:
# Empty DataFrame
# Columns: [KEY, SSEGURO_p, SSEGURO_s]
# Index: []

# %%
### CAGENTE

dfp1 = dfp[['KEY', 'CAGENTE']]
dfs1 = dfs[['KEY', 'CAGENTE']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.CAGENTE_p != dfm.CAGENTE_s) & (~dfm.CAGENTE_s.isnull())].copy()
dfm1[['KEY','CAGENTE_p','CAGENTE_s']]
# Out:
# Empty DataFrame
# Columns: [KEY, CAGENTE_p, CAGENTE_s]
# Index: []

# %%
### CAGRSEG

dfp1 = dfp[['KEY', 'CAGRSEG']]
dfs1 = dfs[['KEY', 'CAGRSEG']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.CAGRSEG_p != dfm.CAGRSEG_s) & (~dfm.CAGRSEG_s.isnull())].copy()
dfm1[['KEY','CAGRSEG_p','CAGRSEG_s']]
# Out:
#                       KEY CAGRSEG_p CAGRSEG_s
# 1296343  61389932-1-LIBER       NaN      4609
# 1300758  61397275-1-LIBER       NaN      4598
# 1371291  61502522-1-LIBER       NaN      4602
# 1373638  61506410-1-LIBER       NaN      4598

# %%
### POLIZA

dfp1 = dfp[['KEY', 'POLIZA']]
dfs1 = dfs[['KEY', 'POLIZA']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.POLIZA_p != dfm.POLIZA_s) & (~dfm.POLIZA_s.isnull())].copy()
dfm1[['KEY','POLIZA_p','POLIZA_s']]
# Out:
# Empty DataFrame
# Columns: [KEY, POLIZA_p, POLIZA_s]
# Index: []

# %%
### ITEM

dfp1 = dfp[['KEY', 'ITEM']]
dfs1 = dfs[['KEY', 'ITEM']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.ITEM_p != dfm.ITEM_s) & (~dfm.ITEM_s.isnull())].copy()
dfm1[['KEY','ITEM_p','ITEM_s']]
# Out:
# Empty DataFrame
# Columns: [KEY, ITEM_p, ITEM_s]
# Index: []

# %%
### INI_VIG

dfp1 = dfp[['KEY', 'INI_VIG']]
dfs1 = dfs[['KEY', 'INI_VIG']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.INI_VIG_p != dfm.INI_VIG_s) & (~dfm.INI_VIG_s.isnull())].copy()
dfm1[['KEY','INI_VIG_p','INI_VIG_s']]
# Out:
# Empty DataFrame
# Columns: [KEY, INI_VIG_p, INI_VIG_s]
# Index: []

# %%
### FIN_VIG_ORIG

dfp1 = dfp[['KEY', 'FIN_VIG_ORIG']]
dfs1 = dfs[['KEY', 'FIN_VIG_ORIG']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.FIN_VIG_ORIG_p != dfm.FIN_VIG_ORIG_s) & (~dfm.FIN_VIG_ORIG_s.isnull())].copy()
dfm1[['KEY','FIN_VIG_ORIG_p','FIN_VIG_ORIG_s']]
# Out:
#                       KEY FIN_VIG_ORIG_p FIN_VIG_ORIG_s
# 1276905  61360057-1-LIBER     2022-02-24     2022-03-23
# 1283293  61369068-1-LIBER     2022-03-10     2022-04-30
# 1284336  61370750-1-LIBER     2022-03-31     2022-04-30
# 1284337  61370750-2-LIBER     2022-03-31     2022-04-30
# 1284338  61370750-3-LIBER     2022-03-31     2022-04-30
# 1284339  61370750-4-LIBER     2022-03-31     2022-04-30
# 1291636  61382630-1-LIBER     2022-05-07     2022-06-06
# 1293449  61385279-1-LIBER     2022-05-29     2022-07-25
# 1294374  61386471-1-LIBER     2022-04-20     2022-04-24

# %%
### FIN_VIG_ACT

dfp1 = dfp[['KEY', 'FIN_VIG_ACT']]
dfs1 = dfs[['KEY', 'FIN_VIG_ACT']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.FIN_VIG_ACT_p != dfm.FIN_VIG_ACT_s) & (~dfm.FIN_VIG_ACT_s.isnull())].copy()
dfm1[['KEY','FIN_VIG_ACT_p','FIN_VIG_ACT_s']]
# Out:
#                         KEY FIN_VIG_ACT_p FIN_VIG_ACT_s
# 980762     61005212-1-LIBER    2019-10-27    2018-06-12
# 982400     61006721-1-LIBER    2020-03-22    2019-12-04
# 982786     61007112-1-LIBER    2020-04-18    2020-04-15
# 985407     61010655-1-LIBER    2020-05-04    2019-05-04
# 987666     61014263-1-LIBER    2020-05-15    2019-05-15
# ...                     ...           ...           ...
# 2625488     6988725-1-LIBER    2020-04-10    2019-04-10
# 2627799     6992879-1-LIBER    2020-04-26    2020-03-07
# 2628533     6993907-1-LIBER    2020-04-10    2019-04-10
# 2631788  6997871-1118-LIBER    2022-01-31    2022-01-23
# 2633453   6997931-696-LIBER    2022-01-31    2020-11-02
#
# [11427 rows x 3 columns]

# %%
### DIAS_VIGENTE

dfp1 = dfp[['KEY', 'DIAS_VIGENTE']]
dfs1 = dfs[['KEY', 'DIAS_VIGENTE']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.DIAS_VIGENTE_p != dfm.DIAS_VIGENTE_s) & (~dfm.DIAS_VIGENTE_s.isnull())].copy()
dfm1[['KEY','DIAS_VIGENTE_p','DIAS_VIGENTE_s']]
# Out:
#                         KEY DIAS_VIGENTE_p DIAS_VIGENTE_s
# 980762     61005212-1-LIBER            730            228
# 982400     61006721-1-LIBER            731            622
# 982786     61007112-1-LIBER            731            728
# 985407     61010655-1-LIBER            366              0
# 987666     61014263-1-LIBER            366              0
# ...                     ...            ...            ...
# 2625488     6988725-1-LIBER            366              0
# 2627799     6992879-1-LIBER            366            316
# 2628533     6993907-1-LIBER            366              0
# 2631788  6997871-1118-LIBER             54             46
# 2633453   6997931-696-LIBER            731            276
#
# [11427 rows x 3 columns]

# %%
### DIAS_SUSCRITOS

dfp1 = dfp[['KEY', 'DIAS_SUSCRITOS']]
dfs1 = dfs[['KEY', 'DIAS_SUSCRITOS']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.DIAS_SUSCRITOS_p != dfm.DIAS_SUSCRITOS_s) & (~dfm.DIAS_SUSCRITOS_s.isnull())].copy()
dfm1[['KEY','DIAS_SUSCRITOS_p','DIAS_SUSCRITOS_s']]
# Out:
#                       KEY DIAS_SUSCRITOS_p DIAS_SUSCRITOS_s
# 1276905  61360057-1-LIBER              365              392
# 1283293  61369068-1-LIBER              365              416
# 1284336  61370750-1-LIBER              365              395
# 1284337  61370750-2-LIBER              365              395
# 1284338  61370750-3-LIBER              365              395
# 1284339  61370750-4-LIBER              365              395
# 1291636  61382630-1-LIBER              365              395
# 1293449  61385279-1-LIBER              365              422
# 1294374  61386471-1-LIBER              365              369
# 2133879   6568435-1-LIBER            73000             73E3

# %%
### VEH_CMARCA

dfp1 = dfp[['KEY', 'VEH_CMARCA']]
dfs1 = dfs[['KEY', 'VEH_CMARCA']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.VEH_CMARCA_p != dfm.VEH_CMARCA_s) & (~dfm.VEH_CMARCA_s.isnull())].copy()
dfm1[['KEY','VEH_CMARCA_p','VEH_CMARCA_s']]
# Out:
#                       KEY VEH_CMARCA_p VEH_CMARCA_s
# 984394   61008920-2-LIBER         1000          1E3
# 984844   61009751-1-LIBER         1000          1E3
# 984847   61009755-1-LIBER         1000          1E3
# 985351   61010558-1-LIBER         1000          1E3
# 985716   61011188-1-LIBER         1000          1E3
# ...                   ...          ...          ...
# 2626833   6991002-1-LIBER         1000          1E3
# 2627356   6992067-1-LIBER         1000          1E3
# 2627513   6992364-1-LIBER         1000          1E3
# 2627522   6992379-1-LIBER         1000          1E3
# 2627643   6992618-1-LIBER         1000          1E3
#
# [1235 rows x 3 columns]

# %%
### VEH_CMODELO

dfp1 = dfp[['KEY', 'VEH_CMODELO']]
dfs1 = dfs[['KEY', 'VEH_CMODELO']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.VEH_CMODELO_p != dfm.VEH_CMODELO_s) & (~dfm.VEH_CMODELO_s.isnull())].copy()
dfm1[['KEY','VEH_CMODELO_p','VEH_CMODELO_s']]
# Out:
#                         KEY VEH_CMODELO_p VEH_CMODELO_s
# 1057494  61073246-839-LIBER           505           519
# 1128808  61185197-493-LIBER            16             2
# 1130585  61185204-390-LIBER            16            14
# 1290974    61381585-1-LIBER           111           110
# 1294601    61387080-1-LIBER           408           409
# 1300062    61396267-1-LIBER           459           470
# 1302735  61399275-721-LIBER            10            12
# 1304416    61401619-1-LIBER           408           314
# 1325952    61435618-1-LIBER           406           534
# 1338686    61453992-1-LIBER           432           490
# 1342952    61460695-1-LIBER           301           401
# 1357354    61481994-1-LIBER             3             4
# 1363432    61489402-1-LIBER           103           120
# 1373633    61506402-1-LIBER           105           121
# 2445248   6808312-418-LIBER           103           414

# %%
### VEH_CLASE

dfp1 = dfp[['KEY', 'VEH_CLASE']]
dfs1 = dfs[['KEY', 'VEH_CLASE']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.VEH_CLASE_p != dfm.VEH_CLASE_s) & (~dfm.VEH_CLASE_s.isnull())].copy()
dfm1[['KEY','VEH_CLASE_p','VEH_CLASE_s']]
# Out:
#                          KEY VEH_CLASE_p VEH_CLASE_s
# 2468150  6816085-14716-LIBER           P           L

# %%
### VEH_CVERSION

dfp1 = dfp[['KEY', 'VEH_CVERSION']]
dfs1 = dfs[['KEY', 'VEH_CVERSION']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.VEH_CVERSION_p != dfm.VEH_CVERSION_s) & (~dfm.VEH_CVERSION_s.isnull())].copy()
dfm1[['KEY','VEH_CVERSION_p','VEH_CVERSION_s']]
# Out:
#                          KEY VEH_CVERSION_p VEH_CVERSION_s
# 1056356   61073224-169-LIBER       39478005       39478001
# 1056464  61073246-1006-LIBER     1368001003     1368001001
# 1057494   61073246-839-LIBER       48505001       48519002
# 1127178    61185183-49-LIBER       41408015       41408001
# 1128808   61185197-493-LIBER      407016001     1335002001
# ...                      ...            ...            ...
# 2546852   6876390-3073-LIBER       77417021       77417058
# 2620061   6982323-1312-LIBER       66105013       66105012
# 2620086   6982323-1335-LIBER       25215003       25215001
# 2620090   6982323-1339-LIBER       78429006       78429001
# 2620166   6982323-1409-LIBER       66303004       66303001
#
# [411 rows x 3 columns]

# %%
### TVERSION

dfp1 = dfp[['KEY', 'TVERSION']]
dfs1 = dfs[['KEY', 'TVERSION']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.TVERSION_p != dfm.TVERSION_s) & (~dfm.TVERSION_s.isnull())].copy()
dfm1[['KEY','TVERSION_p','TVERSION_s']]
# Out:
#                         KEY               TVERSION_p           TVERSION_s
# 995082     61026903-1-LIBER           Q7 2.0 AT TFSI           Q7 AT TFSI
# 996352     61029570-1-LIBER                 IS 250 C        IS 250 CABRIO
# 1054313    61070686-1-LIBER              Q50 HIBRIDO  Q50 HIBRIDO 2.0L AT
# 1054968    61071664-1-LIBER              Q50 HIBRIDO  Q50 HIBRIDO 2.0L AT
# 1055975    61072742-1-LIBER                 IS 250 C        IS 250 CABRIO
# ...                     ...                      ...                  ...
# 2620086  6982323-1335-LIBER                HRV EX MT                  HRV
# 2620090  6982323-1339-LIBER             VERSA 1.8 MT   VERSA SENSE 1.6 MT
# 2620166  6982323-1409-LIBER  SAVEIRO 1.6 /95 P/U STD          SAVEIRO 1.6
# 2624394     6986619-1-LIBER                 IS 250 C        IS 250 CABRIO
# 2628237     6993417-1-LIBER              Q50 HIBRIDO  Q50 HIBRIDO 2.0L AT
#
# [490 rows x 3 columns]

# %%
### USO

dfp1 = dfp[['KEY', 'USO']]
dfs1 = dfs[['KEY', 'USO']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.USO_p != dfm.USO_s) & (~dfm.USO_s.isnull())].copy()
dfm1[['KEY','USO_p','USO_s']]
# Out:
#                        KEY      USO_p        USO_s
# 1221139  61298805-13-LIBER  COMERCIAL  DESCONOCIDO
# 1300062   61396267-1-LIBER  COMERCIAL  DESCONOCIDO

# %%
### VEH_ANO

dfp1 = dfp[['KEY', 'VEH_ANO']]
dfs1 = dfs[['KEY', 'VEH_ANO']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.VEH_ANO_p != dfm.VEH_ANO_s) & (~dfm.VEH_ANO_s.isnull())].copy()
dfm1[['KEY','VEH_ANO_p','VEH_ANO_s']]
# Out:
#                          KEY VEH_ANO_p VEH_ANO_s
# 1304416     61401619-1-LIBER      2019      2021
# 1310435     61411814-1-LIBER      2008      2021
# 1325952     61435618-1-LIBER      2020      2021
# 1376392     61514785-1-LIBER      2019      2020
# 2287731   6724298-2069-LIBER       NaN      2017
# 2468605  6816085-15566-LIBER      2018      2019

# %%
### PATENTE

dfp1 = dfp[['KEY', 'PATENTE']]
dfs1 = dfs[['KEY', 'PATENTE']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.PATENTE_p != dfm.PATENTE_s) & (~dfm.PATENTE_s.isnull())].copy()
dfm1[['KEY','PATENTE_p','PATENTE_s']]
# Out:
#                          KEY PATENTE_p PATENTE_s
# 1031343     61044678-1-LIBER       NaN    LKKB72
# 1056356   61073224-169-LIBER    KVDB52    KBDV52
# 1056464  61073246-1006-LIBER    FACTUR    RCRS54
# 1056541  61073246-1084-LIBER       NaN    LVPX63
# 1057528   61073246-873-LIBER       NaN    LLKK39
# ...                      ...       ...       ...
# 2620090   6982323-1339-LIBER       NaN    JFDV81
# 2620135   6982323-1380-LIBER       NaN    HRKY38
# 2620150   6982323-1394-LIBER       NaN    JKJR20
# 2620166   6982323-1409-LIBER       NaN    FPDV55
# 2620172   6982323-1414-LIBER       NaN    HBSC25
#
# [1572 rows x 3 columns]

# %%
### VEH_CTIPO

dfp1 = dfp[['KEY', 'VEH_CTIPO']]
dfs1 = dfs[['KEY', 'VEH_CTIPO']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.VEH_CTIPO_p != dfm.VEH_CTIPO_s) & (~dfm.VEH_CTIPO_s.isnull())].copy()
dfm1[['KEY','VEH_CTIPO_p','VEH_CTIPO_s']]
# Out:
#                          KEY VEH_CTIPO_p VEH_CTIPO_s
# 1086785      6112042-1-LIBER           2           5
# 1117272     61170309-1-LIBER           2           5
# 1221151     61298807-2-LIBER           2           5
# 1267250     61345720-1-LIBER           2           5
# 1273232     61354706-1-LIBER           5           2
# 1294601     61387080-1-LIBER           5           2
# 1302735   61399275-721-LIBER           1           2
# 1304416     61401619-1-LIBER           5           3
# 1307112     61405822-1-LIBER           5           2
# 1312708     61415217-1-LIBER           2           5
# 1325952     61435618-1-LIBER           5           1
# 1397268      6163225-1-LIBER           2           5
# 1435081      6183598-1-LIBER           2           5
# 1478047      6212681-1-LIBER           2           5
# 1503783      6237514-1-LIBER           2           5
# 1521181      6259399-1-LIBER           2           5
# 1566790      6289253-1-LIBER           2           5
# ...

# %%
### VEH_TIPO

dfp1 = dfp[['KEY', 'VEH_TIPO']]
dfs1 = dfs[['KEY', 'VEH_TIPO']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.VEH_TIPO_p != dfm.VEH_TIPO_s) & (~dfm.VEH_TIPO_s.isnull())].copy()
dfm1[['KEY','VEH_TIPO_p','VEH_TIPO_s']]
# Out:
#                          KEY     VEH_TIPO_p     VEH_TIPO_s
# 1086785      6112042-1-LIBER  STATION WAGON           JEEP
# 1117272     61170309-1-LIBER  STATION WAGON           JEEP
# 1221151     61298807-2-LIBER  STATION WAGON           JEEP
# 1267250     61345720-1-LIBER  STATION WAGON           JEEP
# 1273232     61354706-1-LIBER           JEEP  STATION WAGON
# 1294601     61387080-1-LIBER           JEEP  STATION WAGON
# 1302735   61399275-721-LIBER      AUTOMOVIL  STATION WAGON
# 1304416     61401619-1-LIBER           JEEP      CAMIONETA
# 1307112     61405822-1-LIBER           JEEP  STATION WAGON
# 1312708     61415217-1-LIBER  STATION WAGON           JEEP
# 1325952     61435618-1-LIBER           JEEP      AUTOMOVIL
# 1397268      6163225-1-LIBER  STATION WAGON           JEEP
# 1435081      6183598-1-LIBER  STATION WAGON           JEEP
# 1478047      6212681-1-LIBER  STATION WAGON           JEEP
# 1503783      6237514-1-LIBER  STATION WAGON           JEEP
# ...

# %%
### TMARCA

dfp1 = dfp[['KEY', 'TMARCA']]
dfs1 = dfs[['KEY', 'TMARCA']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.TMARCA_p != dfm.TMARCA_s) & (~dfm.TMARCA_s.isnull())].copy()
dfm1[['KEY','TMARCA_p','TMARCA_s']]
# Out:
#                          KEY  TMARCA_p    TMARCA_s
# 1128808   61185197-493-LIBER  DONGFENG        DFLM
# 1304416     61401619-1-LIBER    NISSAN  MITSUBISHI
# 1325952     61435618-1-LIBER   HYUNDAI   CHEVROLET
# 1701721  6364822-34955-LIBER   CHANGAN       CHERY
# 2445248    6808312-418-LIBER     HONDA       MAZDA

# %%
### TMODELO

dfp1 = dfp[['KEY', 'TMODELO']]
dfs1 = dfs[['KEY', 'TMODELO']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.TMODELO_p != dfm.TMODELO_s) & (~dfm.TMODELO_s.isnull())].copy()
dfm1[['KEY','TMODELO_p','TMODELO_s']]
# Out:
#                          KEY               TMODELO_p    TMODELO_s
# 1057494   61073246-839-LIBER                     308          301
# 1128808   61185197-493-LIBER                  JOYEAR           X3
# 1130585   61185204-390-LIBER                   MS201        MD201
# 1290974     61381585-1-LIBER                     MX6          MX5
# 1294601     61387080-1-LIBER              PATHFINDER      X-TRAIL
# 1300062     61396267-1-LIBER                  JUMPER        JUMPY
# 1302735   61399275-721-LIBER                  ARRIZO      TIGGO 2
# 1304416     61401619-1-LIBER              PATHFINDER         L200
# 1325952     61435618-1-LIBER                SANTA FE         SAIL
# 1338686     61453992-1-LIBER                    VITO      V-CLASS
# 1342664     61460283-1-LIBER  STARIA US4 MB 2.2 CRDI       STARIA
# 1342952     61460695-1-LIBER                 PICK-UP    CARRY ALL
# 1345800     61465717-1-LIBER  STARIA US4 MB 2.2 CRDI       STARIA
# ...

# %%
### NUM_MOTOR

dfp1 = dfp[['KEY', 'NUM_MOTOR']]
dfs1 = dfs[['KEY', 'NUM_MOTOR']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.NUM_MOTOR_p != dfm.NUM_MOTOR_s) & (~dfm.NUM_MOTOR_s.isnull())].copy()
dfm1[['KEY','NUM_MOTOR_p','NUM_MOTOR_s']]
# Out:
#                         KEY      NUM_MOTOR_p      NUM_MOTOR_s
# 1119320  61173532-185-LIBER  sqdr4g15bafmg01  SQDR4G15BAFMG01
# 1273232    61354706-1-LIBER     XZJAJ8680494    XZJAK87422050
# 1285813    61373087-1-LIBER   f18d4183100010   F18D4183100010
# 1286014    61373334-1-LIBER    10Q4EB0011696    10Q4EB0011698
# 1288059    61376712-1-LIBER     SA2PFJ314630    SA2P FJ314630
# ...                     ...              ...              ...
# 2539330  6874448-5047-LIBER  L2B*8M52021053*    L2B8M52021053
# 2539957   6874454-111-LIBER    lwnf200661051    LWNF200661051
# 2541444  6874456-2514-LIBER   ljo18ka1821208   LJO18KA1821208
# 2620150  6982323-1394-LIBER       CTH233327.        CTH233327
# 2620172  6982323-1414-LIBER     G3HAEN295154     G3HAEM295154
#
# [158 rows x 3 columns]

# %%
### CORREDOR_RUT

dfp1 = dfp[['KEY', 'CORREDOR_RUT']]
dfs1 = dfs[['KEY', 'CORREDOR_RUT']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.CORREDOR_RUT_p != dfm.CORREDOR_RUT_s) & (~dfm.CORREDOR_RUT_s.isnull())].copy()
dfm1[['KEY','CORREDOR_RUT_p','CORREDOR_RUT_s']]
# Out:
# Empty DataFrame
# Columns: [KEY, CORREDOR_RUT_p, CORREDOR_RUT_s]
# Index: []

# %%
### CORREDOR

dfp1 = dfp[['KEY', 'CORREDOR']]
dfs1 = dfs[['KEY', 'CORREDOR']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.CORREDOR_p != dfm.CORREDOR_s) & (~dfm.CORREDOR_s.isnull())].copy()
dfm1[['KEY','CORREDOR_p','CORREDOR_s']]
# Out:
#                       KEY                                CORREDOR_p  \
# 1085586  61118583-1-LIBER  CORRED SEGUROS MARIA C RUIZ BECERRA EIRL
# 1086621  61120212-1-LIBER  CORRED SEGUROS MARIA C RUIZ BECERRA EIRL
# 1089600  61125730-1-LIBER     PROSPECT CHILE CORREDORES SEGUROS SPA
# 1100728  61143141-1-LIBER     PROSPECT CHILE CORREDORES SEGUROS SPA
# 1101726  61144711-1-LIBER     PROSPECT CHILE CORREDORES SEGUROS SPA
# ...                   ...                                       ...
# 1374390  61507716-1-LIBER     PROSPECT CHILE CORREDORES SEGUROS SPA
# 1375017  61509202-1-LIBER     PROSPECT CHILE CORREDORES SEGUROS SPA
# 1375749  61512343-1-LIBER     PROSPECT CHILE CORREDORES SEGUROS SPA
# 1375750  61512344-1-LIBER     PROSPECT CHILE CORREDORES SEGUROS SPA
# 2628691   6994146-1-LIBER  CORRED SEGUROS MARIA C RUIZ BECERRA EIRL
#
#                                                 CORREDOR_s
# 1085586  CORREDORA  SEGUROS MARIA CRISTINA  RUIZ  BECER...
# ...

# %%
### COD_PRODUCTO

dfp1 = dfp[['KEY', 'COD_PRODUCTO']]
dfs1 = dfs[['KEY', 'COD_PRODUCTO']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.COD_PRODUCTO_p != dfm.COD_PRODUCTO_s) & (~dfm.COD_PRODUCTO_s.isnull())].copy()
dfm1[['KEY','COD_PRODUCTO_p','COD_PRODUCTO_s']]
# Out:
# Empty DataFrame
# Columns: [KEY, COD_PRODUCTO_p, COD_PRODUCTO_s]
# Index: []

# %%
### PRODUCTO

dfp1 = dfp[['KEY', 'PRODUCTO']]
dfs1 = dfs[['KEY', 'PRODUCTO']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.PRODUCTO_p != dfm.PRODUCTO_s) & (~dfm.PRODUCTO_s.isnull())].copy()
dfm1[['KEY','PRODUCTO_p','PRODUCTO_s']]
# Out:
# Empty DataFrame
# Columns: [KEY, PRODUCTO_p, PRODUCTO_s]
# Index: []

# %%
### COD_PLAN

dfp1 = dfp[['KEY', 'COD_PLAN']]
dfs1 = dfs[['KEY', 'COD_PLAN']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.COD_PLAN_p != dfm.COD_PLAN_s) & (~dfm.COD_PLAN_s.isnull())].copy()
dfm1[['KEY','COD_PLAN_p','COD_PLAN_s']]
# Out:
#                       KEY COD_PLAN_p COD_PLAN_s
# 1343287  61461187-1-LIBER        729          2

# %%
### PLAN

dfp1 = dfp[['KEY', 'PLAN']]
dfs1 = dfs[['KEY', 'PLAN']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.PLAN_p != dfm.PLAN_s) & (~dfm.PLAN_s.isnull())].copy()
dfm1[['KEY','PLAN_p','PLAN_s']]
# Out:
#                       KEY                   PLAN_p                PLAN_s
# 1343287  61461187-1-LIBER  VEHICULO PARTICULAR WEB  PT Y/O RC PARTICULAR

# %%
### DEDUCIBLE

dfp1 = dfp[['KEY', 'DEDUCIBLE']]
dfs1 = dfs[['KEY', 'DEDUCIBLE']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.DEDUCIBLE_p != dfm.DEDUCIBLE_s) & (~dfm.DEDUCIBLE_s.isnull())].copy()
dfm1[['KEY','DEDUCIBLE_p','DEDUCIBLE_s']]
# Out:
#                       KEY DEDUCIBLE_p DEDUCIBLE_s
# 947559    6066793-1-LIBER           8         7.5
# 947931    6068488-1-LIBER           8         7.5
# 948235    6069500-1-LIBER           8         7.5
# 949337   6071439-15-LIBER           2         1.5
# 949341   6071439-19-LIBER           2         1.5
# ...                   ...         ...         ...
# 2609590   6967378-1-LIBER           2         2.5
# 2619351   6981937-1-LIBER           2         2.5
# 2626819   6990975-1-LIBER           2         2.5
# 2627486   6992326-1-LIBER           2         2.5
# 2640463   6998984-1-LIBER           2         2.5
#
# [1329 rows x 3 columns]

# %%
### DEDUCIBLE_INI

dfp1 = dfp[['KEY', 'DEDUCIBLE_INI']]
dfs1 = dfs[['KEY', 'DEDUCIBLE_INI']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.DEDUCIBLE_INI_p != dfm.DEDUCIBLE_INI_s) & (~dfm.DEDUCIBLE_INI_s.isnull())].copy()
dfm1[['KEY','DEDUCIBLE_INI_p','DEDUCIBLE_INI_s']]
# Out:
#                       KEY DEDUCIBLE_INI_p DEDUCIBLE_INI_s
# 947559    6066793-1-LIBER               8             7.5
# 947931    6068488-1-LIBER               8             7.5
# 948235    6069500-1-LIBER               8             7.5
# 949337   6071439-15-LIBER               2             1.5
# 949341   6071439-19-LIBER               2             1.5
# ...                   ...             ...             ...
# 2609590   6967378-1-LIBER               2             2.5
# 2619351   6981937-1-LIBER               2             2.5
# 2626819   6990975-1-LIBER               2             2.5
# 2627486   6992326-1-LIBER               2             2.5
# 2640463   6998984-1-LIBER               2             2.5
#
# [1300 rows x 3 columns]

# %%
### CONTRATANTE_RUT

dfp1 = dfp[['KEY', 'CONTRATANTE_RUT']]
dfs1 = dfs[['KEY', 'CONTRATANTE_RUT']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.CONTRATANTE_RUT_p != dfm.CONTRATANTE_RUT_s) & (~dfm.CONTRATANTE_RUT_s.isnull())].copy()
dfm1[['KEY','CONTRATANTE_RUT_p','CONTRATANTE_RUT_s']]
# Out:
# Empty DataFrame
# Columns: [KEY, CONTRATANTE_RUT_p, CONTRATANTE_RUT_s]
# Index: []

# %%
### CONTRATANTE_NOMBRE

dfp1 = dfp[['KEY', 'CONTRATANTE_NOMBRE']]
dfs1 = dfs[['KEY', 'CONTRATANTE_NOMBRE']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.CONTRATANTE_NOMBRE_p != dfm.CONTRATANTE_NOMBRE_s) & (~dfm.CONTRATANTE_NOMBRE_s.isnull())].copy()
dfm1[['KEY','CONTRATANTE_NOMBRE_p','CONTRATANTE_NOMBRE_s']]
# Out:
#                         KEY  \
# 935747      6061336-8-LIBER
# 936357   6063061-1458-LIBER
# 936918   6063061-2026-LIBER
# 937052   6063061-2164-LIBER
# 942514   6063062-5636-LIBER
# ...                     ...
# 2631290     6997448-1-LIBER
# 2634038  6997933-1287-LIBER
# 2639889     6998047-1-LIBER
# 2640760     6999619-1-LIBER
# 2640781     6999879-1-LIBER
#
#                                       CONTRATANTE_NOMBRE_p  \
# 935747             GRUPO DE INVERSIONISTAS ASOCIADOS  LTDA
# 936357                                RIVERA PARRA MANFRED
# 936918                                 SOTO CHEUQUETA LUIS
# 937052                            ASPE ZAPATA LUIS SILVERI
# 942514                            RAMIREZ ESCOBAR FERNANDO
# ...                                                    ...
# 2631290  LORENA NATALIA JIMENEZ GARCIA . . LORENA NATAL...
# 2634038                              TORRES TORRES LUCIANO
# 2639889                           BUITRAGO JALIL FRANCISCA
# ...

# %%
### FLOTA1

dfp1 = dfp[['KEY', 'FLOTA1']]
dfs1 = dfs[['KEY', 'FLOTA1']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.FLOTA1_p != dfm.FLOTA1_s) & (~dfm.FLOTA1_s.isnull())].copy()
dfm1[['KEY','FLOTA1_p','FLOTA1_s']]
# Out:
# Empty DataFrame
# Columns: [KEY, FLOTA1_p, FLOTA1_s]
# Index: []

# %%
### NRO_MASIVO

dfp1 = dfp[['KEY', 'NRO_MASIVO']]
dfs1 = dfs[['KEY', 'NRO_MASIVO']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.NRO_MASIVO_p != dfm.NRO_MASIVO_s) & (~dfm.NRO_MASIVO_s.isnull())].copy()
dfm1[['KEY','NRO_MASIVO_p','NRO_MASIVO_s']]
# Out:
#                       KEY     NRO_MASIVO_p     NRO_MASIVO_s
# 1346109  61466188-1-LIBER  120000015367869  120000015422953

# %%
### PRIMA

dfp1 = dfp[['KEY', 'PRIMA']]
dfs1 = dfs[['KEY', 'PRIMA']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.PRIMA_p != dfm.PRIMA_s) & (~dfm.PRIMA_s.isnull())].copy()
dfm1[['KEY','PRIMA_p','PRIMA_s']]
# Out:
#                          KEY PRIMA_p PRIMA_s
# 116      10394219-1349-PENTA    16.0      16
# 295      10394221-1050-PENTA    13.0      13
# 299      10394221-1054-PENTA    18.0      18
# 300      10394221-1055-PENTA    18.0      18
# 310      10394221-1065-PENTA    18.0      18
# ...                      ...     ...     ...
# 2640693      6999370-1-LIBER     6.0       6
# 2640694      6999370-2-LIBER     6.0       6
# 2640702      6999390-1-LIBER     6.0       6
# 2640749      6999476-1-LIBER     5.0       5
# 2640764      6999638-1-LIBER    10.0      10
#
# [83083 rows x 3 columns]

# %%
### PRIMA_TARIFA

dfp1 = dfp[['KEY', 'PRIMA_TARIFA']]
dfs1 = dfs[['KEY', 'PRIMA_TARIFA']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.PRIMA_TARIFA_p != dfm.PRIMA_TARIFA_s) & (~dfm.PRIMA_TARIFA_s.isnull())].copy()
dfm1[['KEY','PRIMA_TARIFA_p','PRIMA_TARIFA_s']]
# Out:
#                         KEY PRIMA_TARIFA_p PRIMA_TARIFA_s
# 0        10361804-264-PENTA            0.0              0
# 1        10361804-265-PENTA            0.0              0
# 2        10362876-754-PENTA            0.0              0
# 3        10362876-755-PENTA            0.0              0
# 4        10392980-700-PENTA            0.0              0
# ...                     ...            ...            ...
# 2640562     6999134-2-LIBER            3.0              3
# 2640575     6999176-1-LIBER           16.0             16
# 2640581     6999189-1-LIBER           16.0             16
# 2640638     6999280-1-LIBER           11.0             11
# 2640764     6999638-1-LIBER           10.0             10
#
# [1012336 rows x 3 columns]

# %%
### DESCUENTO

dfp1 = dfp[['KEY', 'DESCUENTO']]
dfs1 = dfs[['KEY', 'DESCUENTO']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.DESCUENTO_p != dfm.DESCUENTO_s) & (~dfm.DESCUENTO_s.isnull())].copy()
dfm1[['KEY','DESCUENTO_p','DESCUENTO_s']]
# Out:
#                         KEY DESCUENTO_p DESCUENTO_s
# 0        10361804-264-PENTA         0.0           0
# 1        10361804-265-PENTA         0.0           0
# 2        10362876-754-PENTA         0.0           0
# 3        10362876-755-PENTA         0.0           0
# 4        10392980-700-PENTA         0.0           0
# ...                     ...         ...         ...
# 2640787     6999890-1-LIBER         0.0           0
# 2640788     6999892-1-LIBER         0.0           0
# 2640789     6999893-1-LIBER         0.0           0
# 2640790     6999905-2-LIBER         0.0           0
# 2640791     6999905-3-LIBER         0.0           0
#
# [1957575 rows x 3 columns]

# %%
### COMISION

dfp1 = dfp[['KEY', 'COMISION']]
dfs1 = dfs[['KEY', 'COMISION']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.COMISION_p != dfm.COMISION_s) & (~dfm.COMISION_s.isnull())].copy()
dfm1[['KEY','COMISION_p','COMISION_s']]
# Out:
#                       KEY COMISION_p COMISION_s
# 23976    10409827-3-PENTA        0.0          0
# 31438    10418645-1-PENTA        0.0          0
# 32117    10420144-1-PENTA        0.0          0
# 32118    10420145-1-PENTA        0.0          0
# 32300    10420532-1-PENTA        0.0          0
# ...                   ...        ...        ...
# 2629582   6995487-1-LIBER        0.0          0
# 2629619   6995557-1-LIBER        0.0          0
# 2629715   6995705-1-LIBER        0.0          0
# 2631293   6997458-1-LIBER        0.0          0
# 2640523   6999075-1-LIBER        0.0          0
#
# [40893 rows x 3 columns]

# %%
### PRIMA_FINAL

dfp1 = dfp[['KEY', 'PRIMA_FINAL']]
dfs1 = dfs[['KEY', 'PRIMA_FINAL']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.PRIMA_FINAL_p != dfm.PRIMA_FINAL_s) & (~dfm.PRIMA_FINAL_s.isnull())].copy()
dfm1[['KEY','PRIMA_FINAL_p','PRIMA_FINAL_s']]
# Out:
#                          KEY PRIMA_FINAL_p PRIMA_FINAL_s
# 116      10394219-1349-PENTA          16.0            16
# 295      10394221-1050-PENTA          13.0            13
# 299      10394221-1054-PENTA          18.0            18
# 300      10394221-1055-PENTA          18.0            18
# 310      10394221-1065-PENTA          18.0            18
# ...                      ...           ...           ...
# 2640693      6999370-1-LIBER           6.0             6
# 2640694      6999370-2-LIBER           6.0             6
# 2640702      6999390-1-LIBER           6.0             6
# 2640749      6999476-1-LIBER           5.0             5
# 2640764      6999638-1-LIBER          10.0            10
#
# [82684 rows x 3 columns]

# %%
### COD_ENDOSO

dfp1 = dfp[['KEY', 'COD_ENDOSO']]
dfs1 = dfs[['KEY', 'COD_ENDOSO']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.COD_ENDOSO_p != dfm.COD_ENDOSO_s) & (~dfm.COD_ENDOSO_s.isnull())].copy()
dfm1[['KEY','COD_ENDOSO_p','COD_ENDOSO_s']]
# Out:
#                         KEY COD_ENDOSO_p COD_ENDOSO_s
# 0        10361804-264-PENTA          NaN          120
# 1        10361804-265-PENTA          NaN            0
# 2        10362876-754-PENTA          NaN            0
# 3        10362876-755-PENTA          NaN            0
# 4        10392980-700-PENTA          NaN          350
# ...                     ...          ...          ...
# 2640788     6999892-1-LIBER          NaN          100
# 2640789     6999893-1-LIBER          NaN          100
# 2640790     6999905-2-LIBER          NaN          100
# 2640791     6999905-3-LIBER          NaN          100
# 2640792     6999910-1-LIBER          NaN          100
#
# [2640793 rows x 3 columns]

# %%
### TDESCRIP

dfp1 = dfp[['KEY', 'TDESCRIP']]
dfs1 = dfs[['KEY', 'TDESCRIP']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.TDESCRIP_p != dfm.TDESCRIP_s) & (~dfm.TDESCRIP_s.isnull())].copy()
dfm1[['KEY','TDESCRIP_p','TDESCRIP_s']]
# Out:
#                         KEY  \
# 980762     61005212-1-LIBER
# 982400     61006721-1-LIBER
# 982786     61007112-1-LIBER
# 985407     61010655-1-LIBER
# 987666     61014263-1-LIBER
# ...                     ...
# 2625488     6988725-1-LIBER
# 2627799     6992879-1-LIBER
# 2628533     6993907-1-LIBER
# 2631788  6997871-1118-LIBER
# 2633453   6997931-696-LIBER
#
#                                                 TDESCRIP_p  \
# 980762                                                 NaN
# 982400                                                 NaN
# 982786   SE REHABILITA POR NO CORRESPONDER ANULACION DE...
# 985407                               RENOVACION DE CARTERA
# 987666                                                 NaN
# ...                                                    ...
# 2625488                              RENOVACION DE CARTERA
# 2627799                                                NaN
# 2628533                                                NaN
# ...

# %%
### ENDOSO_AGRUP

dfp1 = dfp[['KEY', 'ENDOSO_AGRUP']]
dfs1 = dfs[['KEY', 'ENDOSO_AGRUP']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.ENDOSO_AGRUP_p != dfm.ENDOSO_AGRUP_s) & (~dfm.ENDOSO_AGRUP_s.isnull())].copy()
dfm1[['KEY','ENDOSO_AGRUP_p','ENDOSO_AGRUP_s']]
# Out:
#                        KEY  ENDOSO_AGRUP_p ENDOSO_AGRUP_s
# 980762    61005212-1-LIBER      NUEVA PROD    CANCELACION
# 982400    61006721-1-LIBER      NUEVA PROD    CANCELACION
# 982786    61007112-1-LIBER  REHABILITACION    CANCELACION
# 985407    61010655-1-LIBER      NUEVA PROD    CANCELACION
# 987666    61014263-1-LIBER      NUEVA PROD    CANCELACION
# ...                    ...             ...            ...
# 2632401  6997871-795-LIBER      NUEVA PROD    CANCELACION
# 2632412  6997871-806-LIBER      NUEVA PROD    CANCELACION
# 2632442  6997871-838-LIBER          AJUSTE    CANCELACION
# 2632445  6997871-840-LIBER      NUEVA PROD    CANCELACION
# 2633453  6997931-696-LIBER      NUEVA PROD    CANCELACION
#
# [14836 rows x 3 columns]

# %%
### NOMBRE_CONVENIO

dfp1 = dfp[['KEY', 'NOMBRE_CONVENIO']]
dfs1 = dfs[['KEY', 'NOMBRE_CONVENIO']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.NOMBRE_CONVENIO_p != dfm.NOMBRE_CONVENIO_s) & (~dfm.NOMBRE_CONVENIO_s.isnull())].copy()
dfm1[['KEY','NOMBRE_CONVENIO_p','NOMBRE_CONVENIO_s']]
# Out:
#                       KEY NOMBRE_CONVENIO_p      NOMBRE_CONVENIO_s
# 1296343  61389932-1-LIBER    SIN AGRUPACION  AON LINEAS PERSONALES
# 1300758  61397275-1-LIBER    SIN AGRUPACION  SECURITY MALL VIRTUAL
# 1371291  61502522-1-LIBER    SIN AGRUPACION     "SECURITY PREMIUM"
# 1373638  61506410-1-LIBER    SIN AGRUPACION  SECURITY MALL VIRTUAL

# %%
### FLOTA_CONVENIO

dfp1 = dfp[['KEY', 'FLOTA_CONVENIO']]
dfs1 = dfs[['KEY', 'FLOTA_CONVENIO']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.FLOTA_CONVENIO_p != dfm.FLOTA_CONVENIO_s) & (~dfm.FLOTA_CONVENIO_s.isnull())].copy()
dfm1[['KEY','FLOTA_CONVENIO_p','FLOTA_CONVENIO_s']]
# Out:
#                       KEY FLOTA_CONVENIO_p FLOTA_CONVENIO_s
# 1296343  61389932-1-LIBER              NaN                0
# 1300758  61397275-1-LIBER              NaN                0
# 1371291  61502522-1-LIBER              NaN                0
# 1373638  61506410-1-LIBER              NaN                0

# %%
### SUCURSAL

dfp1 = dfp[['KEY', 'SUCURSAL']]
dfs1 = dfs[['KEY', 'SUCURSAL']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.SUCURSAL_p != dfm.SUCURSAL_s) & (~dfm.SUCURSAL_s.isnull())].copy()
dfm1[['KEY','SUCURSAL_p','SUCURSAL_s']]
# Out:
# Empty DataFrame
# Columns: [KEY, SUCURSAL_p, SUCURSAL_s]
# Index: []

# %%
### COD_SUCURSAL1

dfp1 = dfp[['KEY', 'COD_SUCURSAL1']]
dfs1 = dfs[['KEY', 'COD_SUCURSAL1']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.COD_SUCURSAL1_p != dfm.COD_SUCURSAL1_s) & (~dfm.COD_SUCURSAL1_s.isnull())].copy()
dfm1[['KEY','COD_SUCURSAL1_p','COD_SUCURSAL1_s']]
# Out:
# Empty DataFrame
# Columns: [KEY, COD_SUCURSAL1_p, COD_SUCURSAL1_s]
# Index: []

# %%
### SUMA_ASEG_RC

dfp1 = dfp[['KEY', 'SUMA_ASEG_RC']]
dfs1 = dfs[['KEY', 'SUMA_ASEG_RC']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.SUMA_ASEG_RC_p != dfm.SUMA_ASEG_RC_s) & (~dfm.SUMA_ASEG_RC_s.isnull())].copy()
dfm1[['KEY','SUMA_ASEG_RC_p','SUMA_ASEG_RC_s']]
# Out:
#                       KEY SUMA_ASEG_RC_p SUMA_ASEG_RC_s
# 98726    10439859-1-PENTA              0           0.01
# 100715   10442299-1-PENTA              0           0.01
# 102153   10442790-1-PENTA            500          500.5
# 109001   10449221-1-PENTA              0           0.01
# 109002   10449223-1-PENTA            500          500.5
# ...                   ...            ...            ...
# 2612641   6972389-1-LIBER           1125        1124.86
# 2612769   6972580-1-LIBER           1009        1009.11
# 2612920   6972888-1-LIBER           1209        1208.67
# 2612988   6973006-1-LIBER           1234        1234.03
# 2622505   6983084-1-LIBER           1087        1087.22
#
# [13139 rows x 3 columns]

# %%
### ORIGEN

dfp1 = dfp[['KEY', 'ORIGEN']]
dfs1 = dfs[['KEY', 'ORIGEN']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.ORIGEN_p != dfm.ORIGEN_s) & (~dfm.ORIGEN_s.isnull())].copy()
dfm1[['KEY','ORIGEN_p','ORIGEN_s']]
# Out:
# Empty DataFrame
# Columns: [KEY, ORIGEN_p, ORIGEN_s]
# Index: []

# %%
### ASEGURADO_RUT

dfp1 = dfp[['KEY', 'ASEGURADO_RUT']]
dfs1 = dfs[['KEY', 'ASEGURADO_RUT']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.ASEGURADO_RUT_p != dfm.ASEGURADO_RUT_s) & (~dfm.ASEGURADO_RUT_s.isnull())].copy()
dfm1[['KEY','ASEGURADO_RUT_p','ASEGURADO_RUT_s']]
# Out:
#                       KEY ASEGURADO_RUT_p ASEGURADO_RUT_s
# 1174594  61237358-1-LIBER         5717035        13436108
# 1287201  61375453-1-LIBER        17709743        70229000
# 1334286  61447522-1-LIBER         2744582         7032637

# %%
### ANO_REF_INI

dfp1 = dfp[['KEY', 'ANO_REF_INI']]
dfs1 = dfs[['KEY', 'ANO_REF_INI']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.ANO_REF_INI_p != dfm.ANO_REF_INI_s) & (~dfm.ANO_REF_INI_s.isnull())].copy()
dfm1[['KEY','ANO_REF_INI_p','ANO_REF_INI_s']]
# Out:
# Empty DataFrame
# Columns: [KEY, ANO_REF_INI_p, ANO_REF_INI_s]
# Index: []

# %%
### LLAVE

dfp1 = dfp[['KEY', 'LLAVE']]
dfs1 = dfs[['KEY', 'LLAVE']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.LLAVE_p != dfm.LLAVE_s) & (~dfm.LLAVE_s.isnull())].copy()
dfm1[['KEY','LLAVE_p','LLAVE_s']]
# Out:
# Empty DataFrame
# Columns: [KEY, LLAVE_p, LLAVE_s]
# Index: []

# %%
### NUM_ITEMS_CONTRA

dfp1 = dfp[['KEY', 'NUM_ITEMS_CONTRA']]
dfs1 = dfs[['KEY', 'NUM_ITEMS_CONTRA']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.NUM_ITEMS_CONTRA_p != dfm.NUM_ITEMS_CONTRA_s) & (~dfm.NUM_ITEMS_CONTRA_s.isnull())].copy()
dfm1[['KEY','NUM_ITEMS_CONTRA_p','NUM_ITEMS_CONTRA_s']]
# Out:
#                          KEY NUM_ITEMS_CONTRA_p NUM_ITEMS_CONTRA_s
# 985407      61010655-1-LIBER                  1                  0
# 987666      61014263-1-LIBER                  1                  0
# 988196      61015162-1-LIBER                  1                  0
# 1008229  61034916-7906-LIBER                  0                  1
# 1008285  61034916-7965-LIBER                  0                  1
# ...                      ...                ...                ...
# 2620188   6982323-1429-LIBER               1137               2166
# 2620190   6982323-1430-LIBER               1137               2166
# 2620191   6982323-1431-LIBER               1137               2166
# 2625488      6988725-1-LIBER                  1                  0
# 2628533      6993907-1-LIBER                  2                  1
#
# [123854 rows x 3 columns]

# %%
### FLOTA_CONTRA

dfp1 = dfp[['KEY', 'FLOTA_CONTRA']]
dfs1 = dfs[['KEY', 'FLOTA_CONTRA']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.FLOTA_CONTRA_p != dfm.FLOTA_CONTRA_s) & (~dfm.FLOTA_CONTRA_s.isnull())].copy()
dfm1[['KEY','FLOTA_CONTRA_p','FLOTA_CONTRA_s']]
# Out:
#                        KEY FLOTA_CONTRA_p FLOTA_CONTRA_s
# 1285486  61372583-25-LIBER              0              1

# %%
### COD_CONVENIO

dfp1 = dfp[['KEY', 'COD_CONVENIO']]
dfs1 = dfs[['KEY', 'COD_CONVENIO']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.COD_CONVENIO_p != dfm.COD_CONVENIO_s) & (~dfm.COD_CONVENIO_s.isnull())].copy()
dfm1[['KEY','COD_CONVENIO_p','COD_CONVENIO_s']]
# Out:
#                       KEY COD_CONVENIO_p COD_CONVENIO_s
# 1296343  61389932-1-LIBER              0           4609
# 1300758  61397275-1-LIBER              0           4598
# 1371291  61502522-1-LIBER              0           4602
# 1373638  61506410-1-LIBER              0           4598

# %%
### FLOTA

dfp1 = dfp[['KEY', 'FLOTA']]
dfs1 = dfs[['KEY', 'FLOTA']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.FLOTA_p != dfm.FLOTA_s) & (~dfm.FLOTA_s.isnull())].copy()
dfm1[['KEY','FLOTA_p','FLOTA_s']]
# Out:
# Empty DataFrame
# Columns: [KEY, FLOTA_p, FLOTA_s]
# Index: []

# %%
### COD_SUCURSAL

dfp1 = dfp[['KEY', 'COD_SUCURSAL']]
dfs1 = dfs[['KEY', 'COD_SUCURSAL']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.COD_SUCURSAL_p != dfm.COD_SUCURSAL_s) & (~dfm.COD_SUCURSAL_s.isnull())].copy()
dfm1[['KEY','COD_SUCURSAL_p','COD_SUCURSAL_s']]
# Out:
# Empty DataFrame
# Columns: [KEY, COD_SUCURSAL_p, COD_SUCURSAL_s]
# Index: []

# %%
### LC_MODEL

dfp1 = dfp[['KEY', 'LC_MODEL']]
dfs1 = dfs[['KEY', 'LC_MODEL']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.LC_MODEL_p != dfm.LC_MODEL_s) & (~dfm.LC_MODEL_s.isnull())].copy()
dfm1[['KEY','LC_MODEL_p','LC_MODEL_s']]
# Out:
# Empty DataFrame
# Columns: [KEY, LC_MODEL_p, LC_MODEL_s]
# Index: []

# %%
### LC_MODEL_DEF

dfp1 = dfp[['KEY', 'LC_MODEL_DEF']]
dfs1 = dfs[['KEY', 'LC_MODEL_DEF']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.LC_MODEL_DEF_p != dfm.LC_MODEL_DEF_s) & (~dfm.LC_MODEL_DEF_s.isnull())].copy()
dfm1[['KEY','LC_MODEL_DEF_p','LC_MODEL_DEF_s']]
# Out:
# Empty DataFrame
# Columns: [KEY, LC_MODEL_DEF_p, LC_MODEL_DEF_s]
# Index: []

# %%
### MES_REF_INI

dfp1 = dfp[['KEY', 'MES_REF_INI']]
dfs1 = dfs[['KEY', 'MES_REF_INI']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.MES_REF_INI_p != dfm.MES_REF_INI_s) & (~dfm.MES_REF_INI_s.isnull())].copy()
dfm1[['KEY','MES_REF_INI_p','MES_REF_INI_s']]
# Out:
# Empty DataFrame
# Columns: [KEY, MES_REF_INI_p, MES_REF_INI_s]
# Index: []

# %%
### PRIMA_RECIBO

dfp1 = dfp[['KEY', 'PRIMA_RECIBO']]
dfs1 = dfs[['KEY', 'PRIMA_RECIBO']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.PRIMA_RECIBO_p != dfm.PRIMA_RECIBO_s) & (~dfm.PRIMA_RECIBO_s.isnull())].copy()
dfm1[['KEY','PRIMA_RECIBO_p','PRIMA_RECIBO_s']]
# Out:
#                         KEY PRIMA_RECIBO_p PRIMA_RECIBO_s
# 0        10361804-264-PENTA            NaN              0
# 1        10361804-265-PENTA            NaN              0
# 2        10362876-754-PENTA            NaN              0
# 3        10362876-755-PENTA            NaN              0
# 4        10392980-700-PENTA            NaN              0
# ...                     ...            ...            ...
# 2640694     6999370-2-LIBER            6.0              6
# 2640695     6999370-3-LIBER            6.0              6
# 2640702     6999390-1-LIBER            6.0              6
# 2640749     6999476-1-LIBER            5.0              5
# 2640764     6999638-1-LIBER           10.0             10
#
# [1045099 rows x 3 columns]

# %%
### PRIMA_RECIBO_FINAL

dfp1 = dfp[['KEY', 'PRIMA_RECIBO_FINAL']]
dfs1 = dfs[['KEY', 'PRIMA_RECIBO_FINAL']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.PRIMA_RECIBO_FINAL_p != dfm.PRIMA_RECIBO_FINAL_s) & (~dfm.PRIMA_RECIBO_FINAL_s.isnull())].copy()
dfm1[['KEY','PRIMA_RECIBO_FINAL_p','PRIMA_RECIBO_FINAL_s']]
# Out:
#                         KEY PRIMA_RECIBO_FINAL_p PRIMA_RECIBO_FINAL_s
# 0        10361804-264-PENTA                  NaN                    0
# 1        10361804-265-PENTA                  NaN                    0
# 2        10362876-754-PENTA                  NaN                    0
# 3        10362876-755-PENTA                  NaN                    0
# 4        10392980-700-PENTA                  NaN                    0
# ...                     ...                  ...                  ...
# 2640764     6999638-1-LIBER                 10.0                   10
# 2640774     6999751-1-LIBER                  0.0                    0
# 2640777     6999770-1-LIBER                  0.0                    0
# 2640781     6999879-1-LIBER                  0.0                    0
# 2640784     6999884-1-LIBER                  0.0                    0
#
# [1240286 rows x 3 columns]

# %%
### COB_INI

dfp1 = dfp[['KEY', 'COB_INI']]
dfs1 = dfs[['KEY', 'COB_INI']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.COB_INI_p != dfm.COB_INI_s) & (~dfm.COB_INI_s.isnull())].copy()
dfm1[['KEY','COB_INI_p','COB_INI_s']]
# Out:
# Empty DataFrame
# Columns: [KEY, COB_INI_p, COB_INI_s]
# Index: []

# %%
### COB_FIN

dfp1 = dfp[['KEY', 'COB_FIN']]
dfs1 = dfs[['KEY', 'COB_FIN']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.COB_FIN_p != dfm.COB_FIN_s) & (~dfm.COB_FIN_s.isnull())].copy()
dfm1[['KEY','COB_FIN_p','COB_FIN_s']]
# Out:
#                       KEY COB_FIN_p COB_FIN_s
# 1285734  61372973-1-LIBER    126963    133054
# 1288364  61377225-1-LIBER    133056    133054
# 1301429  61398207-1-LIBER    133056    133053
# 1301788  61398739-1-LIBER    126963    133054
# 1305807  61403767-1-LIBER    133057    133054
# 1310479  61411881-1-LIBER    120417    126510
# 1316341  61420928-1-LIBER    126431    133054
# 1327880  61438186-1-LIBER    126962    133053
# 1330875  61442538-1-LIBER     96172    102265
# 1332283  61444798-1-LIBER    126963    133054
# 1335435  61449188-1-LIBER    126962    133053
# 1335999  61450001-1-LIBER     96172    102295
# 1336000  61450003-1-LIBER     96172    102295
# 1341134  61457756-1-LIBER    133059    133057
# 1343287  61461187-1-LIBER    126962     90168
# 1345088  61464332-1-LIBER    120340    126431
# 1351700  61473984-1-LIBER    108388    102265
# 1354902  61478430-1-LIBER    133054    126431
# 1359117  61484397-1-LIBER    120340    126431
# ...

# %%
### FECHA_COTRENOV

dfp1 = dfp[['KEY', 'FECHA_COTRENOV']]
dfs1 = dfs[['KEY', 'FECHA_COTRENOV']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.FECHA_COTRENOV_p != dfm.FECHA_COTRENOV_s) & (~dfm.FECHA_COTRENOV_s.isnull())].copy()
dfm1[['KEY','FECHA_COTRENOV_p','FECHA_COTRENOV_s']]
# Out:
# Empty DataFrame
# Columns: [KEY, FECHA_COTRENOV_p, FECHA_COTRENOV_s]
# Index: []

# %%
### PLAN_DESC

dfp1 = dfp[['KEY', 'PLAN_DESC']]
dfs1 = dfs[['KEY', 'PLAN_DESC']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.PLAN_DESC_p != dfm.PLAN_DESC_s) & (~dfm.PLAN_DESC_s.isnull())].copy()
dfm1[['KEY','PLAN_DESC_p','PLAN_DESC_s']]
# Out:
#                       KEY   PLAN_DESC_p        PLAN_DESC_s
# 1343287  61461187-1-LIBER  RC + DM + RO  DM + RC + PT + RO

# %%
### TIPO_PLAN

dfp1 = dfp[['KEY', 'TIPO_PLAN']]
dfs1 = dfs[['KEY', 'TIPO_PLAN']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.TIPO_PLAN_p != dfm.TIPO_PLAN_s) & (~dfm.TIPO_PLAN_s.isnull())].copy()
dfm1[['KEY','TIPO_PLAN_p','TIPO_PLAN_s']]
# Out:
# Empty DataFrame
# Columns: [KEY, TIPO_PLAN_p, TIPO_PLAN_s]
# Index: []

# %%
### ANTERIOR

dfp1 = dfp[['KEY', 'ANTERIOR']]
dfs1 = dfs[['KEY', 'ANTERIOR']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.ANTERIOR_p != dfm.ANTERIOR_s) & (~dfm.ANTERIOR_s.isnull())].copy()
dfm1[['KEY','ANTERIOR_p','ANTERIOR_s']]
# Out:
# Empty DataFrame
# Columns: [KEY, ANTERIOR_p, ANTERIOR_s]
# Index: []

# %%
### NUM_ITEMS

dfp1 = dfp[['KEY', 'NUM_ITEMS']]
dfs1 = dfs[['KEY', 'NUM_ITEMS']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.NUM_ITEMS_p != dfm.NUM_ITEMS_s) & (~dfm.NUM_ITEMS_s.isnull())].copy()
dfm1[['KEY','NUM_ITEMS_p','NUM_ITEMS_s']]
# Out:
#                         KEY NUM_ITEMS_p NUM_ITEMS_s
# 1056292    61073224-1-LIBER         167         422
# 1056293   61073224-10-LIBER         167         422
# 1056294  61073224-100-LIBER         167         422
# 1056295  61073224-102-LIBER         167         422
# 1056296  61073224-103-LIBER         167         422
# ...                     ...         ...         ...
# 2621078   6982323-995-LIBER        1391        1452
# 2621079   6982323-996-LIBER        1391        1452
# 2621080   6982323-997-LIBER        1391        1452
# 2621081   6982323-998-LIBER        1391        1452
# 2621082   6982323-999-LIBER        1391        1452
#
# [505101 rows x 3 columns]

# %%
### COD_MARCA_P

dfp1 = dfp[['KEY', 'COD_MARCA_P']]
dfs1 = dfs[['KEY', 'COD_MARCA_P']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.COD_MARCA_P_p != dfm.COD_MARCA_P_s) & (~dfm.COD_MARCA_P_s.isnull())].copy()
dfm1[['KEY','COD_MARCA_P_p','COD_MARCA_P_s']]
# Out:
# Empty DataFrame
# Columns: [KEY, COD_MARCA_P_p, COD_MARCA_P_s]
# Index: []

# %%
### COD_MODELO_P

dfp1 = dfp[['KEY', 'COD_MODELO_P']]
dfs1 = dfs[['KEY', 'COD_MODELO_P']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.COD_MODELO_P_p != dfm.COD_MODELO_P_s) & (~dfm.COD_MODELO_P_s.isnull())].copy()
dfm1[['KEY','COD_MODELO_P_p','COD_MODELO_P_s']]
# Out:
# Empty DataFrame
# Columns: [KEY, COD_MODELO_P_p, COD_MODELO_P_s]
# Index: []

# %%
### COD_TIPO_P

dfp1 = dfp[['KEY', 'COD_TIPO_P']]
dfs1 = dfs[['KEY', 'COD_TIPO_P']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.COD_TIPO_P_p != dfm.COD_TIPO_P_s) & (~dfm.COD_TIPO_P_s.isnull())].copy()
dfm1[['KEY','COD_TIPO_P_p','COD_TIPO_P_s']]
# Out:
# Empty DataFrame
# Columns: [KEY, COD_TIPO_P_p, COD_TIPO_P_s]
# Index: []

# %%
### CANAL

dfp1 = dfp[['KEY', 'CANAL']]
dfs1 = dfs[['KEY', 'CANAL']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.CANAL_p != dfm.CANAL_s) & (~dfm.CANAL_s.isnull())].copy()
dfm1[['KEY','CANAL_p','CANAL_s']]
# Out:
# Empty DataFrame
# Columns: [KEY, CANAL_p, CANAL_s]
# Index: []

# %%
### DURACION_PLAN

dfp1 = dfp[['KEY', 'DURACION_PLAN']]
dfs1 = dfs[['KEY', 'DURACION_PLAN']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.DURACION_PLAN_p != dfm.DURACION_PLAN_s) & (~dfm.DURACION_PLAN_s.isnull())].copy()
dfm1[['KEY','DURACION_PLAN_p','DURACION_PLAN_s']]
# Out:
# Empty DataFrame
# Columns: [KEY, DURACION_PLAN_p, DURACION_PLAN_s]
# Index: []

# %%
### ORIGEN_MARCA

dfp1 = dfp[['KEY', 'ORIGEN_MARCA']]
dfs1 = dfs[['KEY', 'ORIGEN_MARCA']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.ORIGEN_MARCA_p != dfm.ORIGEN_MARCA_s) & (~dfm.ORIGEN_MARCA_s.isnull())].copy()
dfm1[['KEY','ORIGEN_MARCA_p','ORIGEN_MARCA_s']]
# Out:
#                         KEY ORIGEN_MARCA_p  ORIGEN_MARCA_s
# 1128808  61185197-493-LIBER          CHINA     DESCONOCIDO
# 1325952    61435618-1-LIBER  COREA DEL SUR  ESTADOS UNIDOS

# %%
### ANTIG_VEHICULO

dfp1 = dfp[['KEY', 'ANTIG_VEHICULO']]
dfs1 = dfs[['KEY', 'ANTIG_VEHICULO']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.ANTIG_VEHICULO_p != dfm.ANTIG_VEHICULO_s) & (~dfm.ANTIG_VEHICULO_s.isnull())].copy()
dfm1[['KEY','ANTIG_VEHICULO_p','ANTIG_VEHICULO_s']]
# Out:
#                          KEY ANTIG_VEHICULO_p ANTIG_VEHICULO_s
# 1304416     61401619-1-LIBER                2                0
# 1310435     61411814-1-LIBER               13                0
# 1325952     61435618-1-LIBER                1                0
# 1376392     61514785-1-LIBER                3                2
# 2287731   6724298-2069-LIBER              NaN                4
# 2468605  6816085-15566-LIBER                3                2

# %%
### PT_RO

dfp1 = dfp[['KEY', 'PT_RO']]
dfs1 = dfs[['KEY', 'PT_RO']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.PT_RO_p != dfm.PT_RO_s) & (~dfm.PT_RO_s.isnull())].copy()
dfm1[['KEY','PT_RO_p','PT_RO_s']]
# Out:
# Empty DataFrame
# Columns: [KEY, PT_RO_p, PT_RO_s]
# Index: []

# %%
### DATE_UPDATE

dfp1 = dfp[['KEY', 'DATE_UPDATE']]
dfs1 = dfs[['KEY', 'DATE_UPDATE']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.DATE_UPDATE_p != dfm.DATE_UPDATE_s) & (~dfm.DATE_UPDATE_s.isnull())].copy()
dfm1[['KEY','DATE_UPDATE_p','DATE_UPDATE_s']]
# Out:
#                         KEY DATE_UPDATE_p DATE_UPDATE_s
# 0        10361804-264-PENTA    2022-03-02    2022-06-05
# 1        10361804-265-PENTA    2022-03-02    2022-06-05
# 2        10362876-754-PENTA    2022-03-02    2022-06-05
# 3        10362876-755-PENTA    2022-03-02    2022-06-05
# 4        10392980-700-PENTA    2022-03-02    2022-06-05
# ...                     ...           ...           ...
# 2640788     6999892-1-LIBER    2022-03-02    2022-06-05
# 2640789     6999893-1-LIBER    2022-03-02    2022-06-05
# 2640790     6999905-2-LIBER    2022-03-02    2022-06-05
# 2640791     6999905-3-LIBER    2022-03-02    2022-06-05
# 2640792     6999910-1-LIBER    2022-03-02    2022-06-05
#
# [2640793 rows x 3 columns]

# %%
### FORMA_PAGO_INI

dfp1 = dfp[['KEY', 'FORMA_PAGO_INI']]
dfs1 = dfs[['KEY', 'FORMA_PAGO_INI']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.FORMA_PAGO_INI_p != dfm.FORMA_PAGO_INI_s) & (~dfm.FORMA_PAGO_INI_s.isnull())].copy()
dfm1[['KEY','FORMA_PAGO_INI_p','FORMA_PAGO_INI_s']]
# Out:
#                       KEY FORMA_PAGO_INI_p FORMA_PAGO_INI_s
# 1371350  61502644-1-LIBER              NaN      AVISO CUOTA
# 1372382  61504500-1-LIBER              NaN     PAGO CONTADO
# 1374633  61508196-1-LIBER              NaN              PAC
# 1374635  61508200-1-LIBER              NaN              PAC
# 1374820  61508639-1-LIBER              NaN      AVISO CUOTA

# %%
### FORMA_PAGO_FIN

dfp1 = dfp[['KEY', 'FORMA_PAGO_FIN']]
dfs1 = dfs[['KEY', 'FORMA_PAGO_FIN']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.FORMA_PAGO_FIN_p != dfm.FORMA_PAGO_FIN_s) & (~dfm.FORMA_PAGO_FIN_s.isnull())].copy()
dfm1[['KEY','FORMA_PAGO_FIN_p','FORMA_PAGO_FIN_s']]
# Out:
#                          KEY FORMA_PAGO_FIN_p FORMA_PAGO_FIN_s
# 1006819  61034916-6566-LIBER              NaN         CUPONERA
# 1185374     61252759-1-LIBER              NaN     PAGO CONTADO
# 1354968     61478535-1-LIBER              NaN              PAC
# 1358001     61483046-1-LIBER              NaN              PAT
# 1370641     61501579-1-LIBER              NaN              PAC
# 1371350     61502644-1-LIBER              NaN      AVISO CUOTA
# 1372382     61504500-1-LIBER              NaN     PAGO CONTADO
# 1374633     61508196-1-LIBER              NaN              PAC
# 1374635     61508200-1-LIBER              NaN              PAC
# 1374820     61508639-1-LIBER              NaN      AVISO CUOTA

# %%
### METODO_PAGO

dfp1 = dfp[['KEY', 'METODO_PAGO']]
dfs1 = dfs[['KEY', 'METODO_PAGO']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.METODO_PAGO_p != dfm.METODO_PAGO_s) & (~dfm.METODO_PAGO_s.isnull())].copy()
dfm1[['KEY','METODO_PAGO_p','METODO_PAGO_s']]
# Out:
#                       KEY METODO_PAGO_p METODO_PAGO_s
# 1371350  61502644-1-LIBER           NaN   AVISO CUOTA
# 1372382  61504500-1-LIBER           NaN  PAGO CONTADO
# 1374633  61508196-1-LIBER           NaN           PAC
# 1374635  61508200-1-LIBER           NaN           PAC
# 1374820  61508639-1-LIBER           NaN   AVISO CUOTA

# %%
### RAZON_CUOTAS

dfp1 = dfp[['KEY', 'RAZON_CUOTAS']]
dfs1 = dfs[['KEY', 'RAZON_CUOTAS']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.RAZON_CUOTAS_p != dfm.RAZON_CUOTAS_s) & (~dfm.RAZON_CUOTAS_s.isnull())].copy()
dfm1[['KEY','RAZON_CUOTAS_p','RAZON_CUOTAS_s']]
# Out:
#                       KEY RAZON_CUOTAS_p   RAZON_CUOTAS_s
# 1104029  61148971-1-LIBER            NaN       Excedentes
# 1173069  61235068-1-LIBER            NaN       Excedentes
# 1173143  61235179-1-LIBER            NaN  Redocumentacion
# 1173146  61235182-1-LIBER            NaN       Excedentes
# 1173156  61235196-1-LIBER            NaN       Excedentes
# ...                   ...            ...              ...
# 1376545  61515280-1-LIBER            NaN       Excedentes
# 1376546  61515281-1-LIBER            NaN  Redocumentacion
# 1376547  61515282-1-LIBER            NaN       Excedentes
# 1376548  61515283-1-LIBER            NaN  Redocumentacion
# 1376549  61515284-1-LIBER            NaN  Redocumentacion
#
# [3202 rows x 3 columns]

# %%
### TUVO_PT

dfp1 = dfp[['KEY', 'TUVO_PT']]
dfs1 = dfs[['KEY', 'TUVO_PT']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.TUVO_PT_p != dfm.TUVO_PT_s) & (~dfm.TUVO_PT_s.isnull())].copy()
dfm1[['KEY','TUVO_PT_p','TUVO_PT_s']]
# Out:
#                          KEY TUVO_PT_p TUVO_PT_s
# 986231      61012150-1-LIBER       NaN         1
# 1016406  61034933-2200-LIBER       NaN         1
# 1018452  61034933-4237-LIBER       NaN         1
# 1057209   61073246-559-LIBER       NaN         1
# 1057313   61073246-657-LIBER       NaN         1
# ...                      ...       ...       ...
# 2545903   6876390-2083-LIBER       NaN         1
# 2546364   6876390-2549-LIBER       NaN         1
# 2547234   6876390-3463-LIBER       NaN         1
# 2558496   6889536-1887-LIBER       NaN         1
# 2620075   6982323-1325-LIBER       NaN         1
#
# [348 rows x 3 columns]

# %%
### FORMA_PAGO_DEF

dfp1 = dfp[['KEY', 'FORMA_PAGO_DEF']]
dfs1 = dfs[['KEY', 'FORMA_PAGO_DEF']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.FORMA_PAGO_DEF_p != dfm.FORMA_PAGO_DEF_s) & (~dfm.FORMA_PAGO_DEF_s.isnull())].copy()
dfm1[['KEY','FORMA_PAGO_DEF_p','FORMA_PAGO_DEF_s']]
# Out:
#                       KEY FORMA_PAGO_DEF_p FORMA_PAGO_DEF_s
# 1125166  61181386-1-LIBER      AVISO CUOTA         CUPONERA
# 1153201  61213552-1-LIBER      AVISO CUOTA              PAC
# 1158500  61222569-1-LIBER      AVISO CUOTA              PAC
# 1194602  61259595-1-LIBER              PAT              PAC
# 1201187  61269836-1-LIBER      AVISO CUOTA     PAGO CONTADO
# 1234999  61319532-1-LIBER      AVISO CUOTA              PAT
# 1371350  61502644-1-LIBER              NaN      AVISO CUOTA
# 1372382  61504500-1-LIBER              NaN     PAGO CONTADO
# 1374633  61508196-1-LIBER              NaN              PAC
# 1374635  61508200-1-LIBER              NaN              PAC
# 1374820  61508639-1-LIBER              NaN      AVISO CUOTA

# %%
### TIPO_PERS

dfp1 = dfp[['KEY', 'TIPO_PERS']]
dfs1 = dfs[['KEY', 'TIPO_PERS']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.TIPO_PERS_p != dfm.TIPO_PERS_s) & (~dfm.TIPO_PERS_s.isnull())].copy()
dfm1[['KEY','TIPO_PERS_p','TIPO_PERS_s']]
# Out:
#                       KEY TIPO_PERS_p TIPO_PERS_s
# 1287201  61375453-1-LIBER        PNat        PJur

# %%
### SEXO

dfp1 = dfp[['KEY', 'SEXO']]
dfs1 = dfs[['KEY', 'SEXO']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.SEXO_p != dfm.SEXO_s) & (~dfm.SEXO_s.isnull())].copy()
dfm1[['KEY','SEXO_p','SEXO_s']]
# Out:
#                        KEY SEXO_p SEXO_s
# 1172225  61234181-22-LIBER    NaN      1
# 1172389  61234337-10-LIBER    NaN      1
# 1174594   61237358-1-LIBER      1      0
# 1337856   61452405-1-LIBER    NaN      1
# 1477990    6212592-1-LIBER      0      1
# 1568516    6291816-1-LIBER      0      1
# 2439801  6808228-118-LIBER    NaN      0
# 2439859  6808228-173-LIBER    NaN      0
# 2439905  6808228-214-LIBER    NaN      0
# 2439952   6808228-56-LIBER    NaN      0

# %%
### NACIONALIDAD

dfp1 = dfp[['KEY', 'NACIONALIDAD']]
dfs1 = dfs[['KEY', 'NACIONALIDAD']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.NACIONALIDAD_p != dfm.NACIONALIDAD_s) & (~dfm.NACIONALIDAD_s.isnull())].copy()
dfm1[['KEY','NACIONALIDAD_p','NACIONALIDAD_s']]
# Out:
# Empty DataFrame
# Columns: [KEY, NACIONALIDAD_p, NACIONALIDAD_s]
# Index: []

# %%
### SEXO_ASEGURADO

dfp1 = dfp[['KEY', 'SEXO_ASEGURADO']]
dfs1 = dfs[['KEY', 'SEXO_ASEGURADO']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.SEXO_ASEGURADO_p != dfm.SEXO_ASEGURADO_s) & (~dfm.SEXO_ASEGURADO_s.isnull())].copy()
dfm1[['KEY','SEXO_ASEGURADO_p','SEXO_ASEGURADO_s']]
# Out:
#                        KEY SEXO_ASEGURADO_p SEXO_ASEGURADO_s
# 1172225  61234181-22-LIBER              NaN                F
# 1172389  61234337-10-LIBER              NaN                F
# 1174594   61237358-1-LIBER                F                M
# 1337856   61452405-1-LIBER              NaN                F
# 1477990    6212592-1-LIBER                M                F
# 1568516    6291816-1-LIBER                M                F
# 2439801  6808228-118-LIBER              NaN                M
# 2439859  6808228-173-LIBER              NaN                M
# 2439905  6808228-214-LIBER              NaN                M
# 2439952   6808228-56-LIBER              NaN                M

# %%
### FECHA_NACIMIENTO

dfp1 = dfp[['KEY', 'FECHA_NACIMIENTO']]
dfs1 = dfs[['KEY', 'FECHA_NACIMIENTO']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.FECHA_NACIMIENTO_p != dfm.FECHA_NACIMIENTO_s) & (~dfm.FECHA_NACIMIENTO_s.isnull())].copy()
dfm1[['KEY','FECHA_NACIMIENTO_p','FECHA_NACIMIENTO_s']]
# Out:
#                       KEY FECHA_NACIMIENTO_p FECHA_NACIMIENTO_s
# 1174594  61237358-1-LIBER         1952-07-29         1978-11-26
# 1337856  61452405-1-LIBER                NaN         1955-02-02
# 1436709   6186057-1-LIBER                NaN         1962-06-01
# 1452271   6197563-1-LIBER                NaN         1941-10-16
# 1477990   6212592-1-LIBER                NaN         1973-10-01
# 1509652   6243644-1-LIBER                NaN         1992-07-21
# 1562279   6282280-1-LIBER                NaN         1979-05-23
# 1568516   6291816-1-LIBER                NaN         1973-10-01
# 1570348   6294406-1-LIBER                NaN         1977-10-26
# 1572370   6297410-1-LIBER                NaN         1958-11-27
# 1617287   6318389-1-LIBER                NaN         1979-09-01
# 1646398   6358318-1-LIBER                NaN         1979-05-23
# 1987906   6378097-1-LIBER                NaN         1977-10-26
# 2013944   6404687-1-LIBER                NaN         1979-09-01
# ...

# %%
### EDAD_ASEGURADO

dfp1 = dfp[['KEY', 'EDAD_ASEGURADO']]
dfs1 = dfs[['KEY', 'EDAD_ASEGURADO']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.EDAD_ASEGURADO_p != dfm.EDAD_ASEGURADO_s) & (~dfm.EDAD_ASEGURADO_s.isnull())].copy()
dfm1[['KEY','EDAD_ASEGURADO_p','EDAD_ASEGURADO_s']]
# Out:
#                       KEY EDAD_ASEGURADO_p EDAD_ASEGURADO_s
# 1174594  61237358-1-LIBER               68               42
# 1337856  61452405-1-LIBER              NaN               66
# 1436709   6186057-1-LIBER              NaN               49
# 1452271   6197563-1-LIBER              NaN               70
# 1477990   6212592-1-LIBER              NaN               39
# 1509652   6243644-1-LIBER              NaN               20
# 1562279   6282280-1-LIBER              NaN               33
# 1568516   6291816-1-LIBER              NaN               40
# 1570348   6294406-1-LIBER              NaN               36
# 1572370   6297410-1-LIBER              NaN               55
# 1617287   6318389-1-LIBER              NaN               34
# 1646398   6358318-1-LIBER              NaN               34
# 1987906   6378097-1-LIBER              NaN               37
# 2013944   6404687-1-LIBER              NaN               35
# 2018735   6406848-1-LIBER              NaN               35

# %%
### ANUL

dfp1 = dfp[['KEY', 'ANUL']]
dfs1 = dfs[['KEY', 'ANUL']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.ANUL_p != dfm.ANUL_s) & (~dfm.ANUL_s.isnull())].copy()
dfm1[['KEY','ANUL_p','ANUL_s']]
# Out:
#                          KEY ANUL_p ANUL_s
# 985407      61010655-1-LIBER      0      1
# 987666      61014263-1-LIBER      0      1
# 988196      61015162-1-LIBER      0      1
# 1009246  61034925-1824-LIBER      0      1
# 1013325  61034925-5996-LIBER      0      1
# ...                      ...    ...    ...
# 2586768    6928066-871-LIBER      0      1
# 2586769    6928066-872-LIBER      0      1
# 2614428    6975053-334-LIBER      0      1
# 2625488      6988725-1-LIBER      0      1
# 2628533      6993907-1-LIBER      0      1
#
# [1246 rows x 3 columns]

# %%
### CANCEL

dfp1 = dfp[['KEY', 'CANCEL']]
dfs1 = dfs[['KEY', 'CANCEL']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.CANCEL_p != dfm.CANCEL_s) & (~dfm.CANCEL_s.isnull())].copy()
dfm1[['KEY','CANCEL_p','CANCEL_s']]
# Out:
#                        KEY CANCEL_p CANCEL_s
# 980762    61005212-1-LIBER        0        1
# 982400    61006721-1-LIBER        0        1
# 982786    61007112-1-LIBER        0        1
# 994266    61025219-1-LIBER        0        1
# 995361    61027420-1-LIBER        0        1
# ...                    ...      ...      ...
# 2632401  6997871-795-LIBER        0        1
# 2632412  6997871-806-LIBER        0        1
# 2632442  6997871-838-LIBER        0        1
# 2632445  6997871-840-LIBER        0        1
# 2633453  6997931-696-LIBER        0        1
#
# [10307 rows x 3 columns]

# %%
### DESCRIPCION

dfp1 = dfp[['KEY', 'DESCRIPCION']]
dfs1 = dfs[['KEY', 'DESCRIPCION']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.DESCRIPCION_p != dfm.DESCRIPCION_s) & (~dfm.DESCRIPCION_s.isnull())].copy()
dfm1[['KEY','DESCRIPCION_p','DESCRIPCION_s']]
# Out:
#                        KEY                         DESCRIPCION_p  \
# 980762    61005212-1-LIBER                      NUEVA PRODUCCION
# 982400    61006721-1-LIBER                      NUEVA PRODUCCION
# 982786    61007112-1-LIBER                        Rehabilitacion
# 985407    61010655-1-LIBER                      NUEVA PRODUCCION
# 987666    61014263-1-LIBER                      NUEVA PRODUCCION
# ...                    ...                                   ...
# 2632401  6997871-795-LIBER                      NUEVA PRODUCCION
# 2632412  6997871-806-LIBER                      NUEVA PRODUCCION
# 2632442  6997871-838-LIBER  Modificacion Datos Riesgos Asegurado
# 2632445  6997871-840-LIBER                      NUEVA PRODUCCION
# 2633453  6997931-696-LIBER                      NUEVA PRODUCCION
#
#                  DESCRIPCION_s
# 980762   CANCELACION ASEGURADO
# 982400      CANCELACION MASIVA
# 982786      CANCELACION MASIVA
# 985407   CANCELACION ASEGURADO
# ...

# %%
### FCANCEL_NEW

dfp1 = dfp[['KEY', 'FCANCEL_NEW']]
dfs1 = dfs[['KEY', 'FCANCEL_NEW']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.FCANCEL_NEW_p != dfm.FCANCEL_NEW_s) & (~dfm.FCANCEL_NEW_s.isnull())].copy()
dfm1[['KEY','FCANCEL_NEW_p','FCANCEL_NEW_s']]
# Out:
#                        KEY FCANCEL_NEW_p FCANCEL_NEW_s
# 929036   6006870-111-LIBER           NaN    17/11/2010
# 934783    6024282-19-LIBER           NaN    27/07/2010
# 934788     6024770-2-LIBER           NaN    06/04/2010
# 934819    6027809-49-LIBER           NaN    04/10/2010
# 934820    6027809-50-LIBER           NaN    04/10/2010
# ...                    ...           ...           ...
# 2640604    6999230-1-LIBER           NaN    06/06/2019
# 2640618    6999248-1-LIBER           NaN    20/04/2020
# 2640680    6999337-1-LIBER           NaN    28/08/2019
# 2640692    6999369-1-LIBER           NaN    26/09/2019
# 2640759    6999554-1-LIBER           NaN    26/11/2019
#
# [37091 rows x 3 columns]

# %%
### MOT_ANT

dfp1 = dfp[['KEY', 'MOT_ANT']]
dfs1 = dfs[['KEY', 'MOT_ANT']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.MOT_ANT_p != dfm.MOT_ANT_s) & (~dfm.MOT_ANT_s.isnull())].copy()
dfm1[['KEY','MOT_ANT_p','MOT_ANT_s']]
# Out:
#                         KEY MOT_ANT_p  MOT_ANT_s
# 0        10361804-264-PENTA       NaN    NO PAGO
# 4        10392980-700-PENTA       NaN         PT
# 5        10392980-702-PENTA       NaN  ASEGURADO
# 7        10392980-704-PENTA       NaN    NO PAGO
# 10       10392980-708-PENTA       NaN    NO PAGO
# ...                     ...       ...        ...
# 2640775     6999757-1-LIBER       NaN    NO PAGO
# 2640777     6999770-1-LIBER       NaN  ASEGURADO
# 2640779     6999873-1-LIBER       NaN  ASEGURADO
# 2640781     6999879-1-LIBER       NaN    NO PAGO
# 2640784     6999884-1-LIBER       NaN    NO PAGO
#
# [985877 rows x 3 columns]

# %%
### MOT_ORIG

dfp1 = dfp[['KEY', 'MOT_ORIG']]
dfs1 = dfs[['KEY', 'MOT_ORIG']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.MOT_ORIG_p != dfm.MOT_ORIG_s) & (~dfm.MOT_ORIG_s.isnull())].copy()
dfm1[['KEY','MOT_ORIG_p','MOT_ORIG_s']]
# Out:
#                         KEY MOT_ORIG_p MOT_ORIG_s
# 0        10361804-264-PENTA        NaN    NO PAGO
# 4        10392980-700-PENTA        NaN         PT
# 5        10392980-702-PENTA        NaN  ASEGURADO
# 7        10392980-704-PENTA        NaN    NO PAGO
# 10       10392980-708-PENTA        NaN    NO PAGO
# ...                     ...        ...        ...
# 2640775     6999757-1-LIBER        NaN    NO PAGO
# 2640777     6999770-1-LIBER        NaN  ASEGURADO
# 2640779     6999873-1-LIBER        NaN  ASEGURADO
# 2640781     6999879-1-LIBER        NaN    NO PAGO
# 2640784     6999884-1-LIBER        NaN    NO PAGO
#
# [985877 rows x 3 columns]

# %%
### MOTIVO_CANCEL_ANUL2

dfp1 = dfp[['KEY', 'MOTIVO_CANCEL_ANUL2']]
dfs1 = dfs[['KEY', 'MOTIVO_CANCEL_ANUL2']]

dfm = pd.merge(dfp1, dfs1, how='left',
left_on=['KEY'],
right_on=['KEY'],
left_index=False,
right_index=False, 
sort=True,
suffixes=('_p', '_s'), copy=True, indicator=False,
validate=None)

dfm1 = dfm.sort_values(['KEY'], ascending=[True])
dfm1 = dfm1.loc[(dfm.MOTIVO_CANCEL_ANUL2_p != dfm.MOTIVO_CANCEL_ANUL2_s) & (~dfm.MOTIVO_CANCEL_ANUL2_s.isnull())].copy()
dfm1[['KEY','MOTIVO_CANCEL_ANUL2_p','MOTIVO_CANCEL_ANUL2_s']]
# Out:
#                         KEY MOTIVO_CANCEL_ANUL2_p MOTIVO_CANCEL_ANUL2_s
# 0        10361804-264-PENTA                   NaN               NO PAGO
# 4        10392980-700-PENTA                   NaN                    PT
# 5        10392980-702-PENTA                   NaN             ASEGURADO
# 7        10392980-704-PENTA                   NaN               NO PAGO
# 10       10392980-708-PENTA                   NaN               NO PAGO
# ...                     ...                   ...                   ...
# 2640775     6999757-1-LIBER                   NaN               NO PAGO
# 2640777     6999770-1-LIBER                   NaN             ASEGURADO
# 2640779     6999873-1-LIBER                   NaN             ASEGURADO
# 2640781     6999879-1-LIBER                   NaN               NO PAGO
# 2640784     6999884-1-LIBER                   NaN               NO PAGO
#
# [985877 rows x 3 columns]

# %%
# final comparacioncampos
